# %% [markdown]
# ### importing excel

# %%
import pandas as pd
data=pd.read_excel('./Desktop/final assessment.xlsx')

# %%
data.head(3)
# Out:
#    Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0   33994  CA-2012-SM20320140-40985 2012-03-17 2012-03-22  Standard Class
# 1   38123  CA-2014-TC20980140-41915 2014-10-03 2014-10-10  Standard Class
# 2   39450  CA-2015-RB19360140-42087 2015-03-24 2015-03-26     First Class
#
#     Customer ID Customer Name      Segment  Postal Code          City  ...  \
# 0  SM-203201408   Sean Miller  Home Office      32216.0  Jacksonville  ...
# 1  TC-209801402  Tamara Chand    Corporate      47905.0     Lafayette  ...
# 2  RB-193601404  Raymond Buch     Consumer      98115.0       Seattle  ...
#
#   Quantity Discount     Profit Shipping Cost Order Priority Person Region.1  \
# 0        6      0.5 -1811.0784      24.28650         Medium    NaN      NaN
# 1        5      0.0  8399.9760     349.07000         Medium    NaN      NaN
# 2        4      0.0  6719.9808      20.00054         Medium    NaN      NaN
#
#   top_4_months   day_nme   avg_sales
# ...

# %%
data.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# Person                    object
# Region.1                  object
# dtype: object

# %% [markdown]
# # 1. To find the total sales and average profit of each country.

# %%
Total_sales = data.groupby('Country')['Sales'].sum()
av_profit = data.groupby('Country')['Profit'].mean()

# %%
Total_sales #total sales of each country
# Out:
# Country
# Afghanistan       21673.32000
# Albania            3888.12000
# Algeria           36091.59000
# Angola            25554.00000
# Argentina         57511.78328
#                      ...
# Vietnam           65210.06580
# Western Sahara      666.36000
# Yemen              2465.71200
# Zambia            26035.50000
# Zimbabwe           3765.10500
# Name: Sales, Length: 165, dtype: float64

# %%
av_profit #avg_profit for each country
# Out:
# Country
# Afghanistan        99.278182
# Albania            44.332500
# Algeria            46.461735
# Angola             53.237459
# Argentina         -47.932812
#                      ...
# Vietnam            -6.453666
# Western Sahara    150.210000
# Yemen            -123.548600
# Zambia             68.644412
# Zimbabwe          -67.859812
# Name: Profit, Length: 165, dtype: float64

# %% [markdown]
# # 2. Find the top 10 customers names based on their spending.

# %%
df=pd.DataFrame(data)

# %%
df.head(3)
# Out:
#    Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0   33994  CA-2012-SM20320140-40985 2012-03-17 2012-03-22  Standard Class
# 1   38123  CA-2014-TC20980140-41915 2014-10-03 2014-10-10  Standard Class
# 2   39450  CA-2015-RB19360140-42087 2015-03-24 2015-03-26     First Class
#
#     Customer ID Customer Name      Segment  Postal Code          City  ...  \
# 0  SM-203201408   Sean Miller  Home Office      32216.0  Jacksonville  ...
# 1  TC-209801402  Tamara Chand    Corporate      47905.0     Lafayette  ...
# 2  RB-193601404  Raymond Buch     Consumer      98115.0       Seattle  ...
#
#   Quantity Discount     Profit Shipping Cost Order Priority Person Region.1  \
# 0        6      0.5 -1811.0784      24.28650         Medium    NaN      NaN
# 1        5      0.0  8399.9760     349.07000         Medium    NaN      NaN
# 2        4      0.0  6719.9808      20.00054         Medium    NaN      NaN
#
#   top_4_months   day_nme   avg_sales
# ...

# %%
data_names=df.sort_values('Sales',ascending=False)

# %%
data_names.head(3)
# Out:
#    Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0   33994  CA-2012-SM20320140-40985 2012-03-17 2012-03-22  Standard Class
# 1   38123  CA-2014-TC20980140-41915 2014-10-03 2014-10-10  Standard Class
# 2   39450  CA-2015-RB19360140-42087 2015-03-24 2015-03-26     First Class
#
#     Customer ID Customer Name      Segment  Postal Code          City  ...  \
# 0  SM-203201408   Sean Miller  Home Office      32216.0  Jacksonville  ...
# 1  TC-209801402  Tamara Chand    Corporate      47905.0     Lafayette  ...
# 2  RB-193601404  Raymond Buch     Consumer      98115.0       Seattle  ...
#
#   Sub-Category                                       Product Name     Sales  \
# 0     Machines  Cisco TelePresence System EX90 Videoconferenci...  22638.48
# 1      Copiers              Canon imageCLASS 2200 Advanced Copier  17499.95
# 2      Copiers              Canon imageCLASS 2200 Advanced Copier  13999.96
#
# ...

# %%
data_names.groupby('Customer Name')['Sales']

# %%
data_names[['Customer Name']].head(10)
# Out:
#         Customer Name
# 0         Sean Miller
# 1        Tamara Chand
# 2        Raymond Buch
# 3        Tom Ashbrook
# 4        Hunter Lopez
# 5       Adrian Barton
# 6        Sanjit Chand
# 7        Bill Shonely
# 8        Sanjit Engle
# 9  Christopher Conant

# %% [markdown]
# # 3. From order date, derive the month of each order and find the top 4 months based on the sales.

# %%
df['top_4_months'] = df['Order Date'].dt.month_name()

# %%
df.head(3)
# Out:
#    Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0   33994  CA-2012-SM20320140-40985 2012-03-17 2012-03-22  Standard Class
# 1   38123  CA-2014-TC20980140-41915 2014-10-03 2014-10-10  Standard Class
# 2   39450  CA-2015-RB19360140-42087 2015-03-24 2015-03-26     First Class
#
#     Customer ID Customer Name      Segment  Postal Code          City  ...  \
# 0  SM-203201408   Sean Miller  Home Office      32216.0  Jacksonville  ...
# 1  TC-209801402  Tamara Chand    Corporate      47905.0     Lafayette  ...
# 2  RB-193601404  Raymond Buch     Consumer      98115.0       Seattle  ...
#
#   Quantity Discount     Profit Shipping Cost Order Priority Person Region.1  \
# 0        6      0.5 -1811.0784      24.28650         Medium    NaN      NaN
# 1        5      0.0  8399.9760     349.07000         Medium    NaN      NaN
# 2        4      0.0  6719.9808      20.00054         Medium    NaN      NaN
#
#   top_4_months   day_nme   avg_sales
# ...

# %%
top_months= df.sort_values('Sales',ascending=False)

# %%
top_months.groupby('top_4_months')['Sales']

# %%
top_months.head(4)
# Out:
#    Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0   33994  CA-2012-SM20320140-40985 2012-03-17 2012-03-22  Standard Class
# 1   38123  CA-2014-TC20980140-41915 2014-10-03 2014-10-10  Standard Class
# 2   39450  CA-2015-RB19360140-42087 2015-03-24 2015-03-26     First Class
# 3   33920  CA-2015-TA21385140-42300 2015-10-23 2015-10-25     First Class
#
#     Customer ID Customer Name      Segment  Postal Code           City  ...  \
# 0  SM-203201408   Sean Miller  Home Office      32216.0   Jacksonville  ...
# 1  TC-209801402  Tamara Chand    Corporate      47905.0      Lafayette  ...
# 2  RB-193601404  Raymond Buch     Consumer      98115.0        Seattle  ...
# 3  TA-213851406  Tom Ashbrook  Home Office      10024.0  New York City  ...
#
#                                         Product Name      Sales Quantity  \
# 0  Cisco TelePresence System EX90 Videoconferenci...  22638.480        6
# ...

# %%
top_months[['top_4_months']].head(4)
# Out:
#   top_4_months
# 0        March
# 1      October
# 2        March
# 3      October

# %% [markdown]
# # 4.From ship date, derive the day name of each order and find the bottom 4 days based on the profit.

# %%
df['day_nme'] = df['Ship Date'].dt.day_name()

# %%
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       33994  CA-2012-SM20320140-40985 2012-03-17 2012-03-22  Standard Class
# 1       38123  CA-2014-TC20980140-41915 2014-10-03 2014-10-10  Standard Class
# 2       39450  CA-2015-RB19360140-42087 2015-03-24 2015-03-26     First Class
# 3       33920  CA-2015-TA21385140-42300 2015-10-23 2015-10-25     First Class
# 4       35487  CA-2015-HL15040140-42326 2015-11-18 2015-11-23  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51285   33403  US-2012-HG14965140-41177 2012-09-25 2012-09-25        Same Day
# 51286   36008  CA-2012-JO15280140-40998 2012-03-30 2012-03-30        Same Day
# 51287   39955  CA-2014-KB16600140-41812 2014-06-22 2014-06-26  Standard Class
# 51288   40589  CA-2015-RS19765140-42066 2015-03-03 2015-03-03        Same Day
# 51289   35398  US-2015-ZC21910140-42175 2015-06-20 2015-06-24  Standard Class
#
# ...

# %%
bottom_4_days = df.sort_values('Profit')

# %%
bottom_4_days[['day_nme']].head(4)
# Out:
#        day_nme
# 61   Wednesday
# 208     Friday
# 12    Thursday
# 575     Sunday

# %% [markdown]
# # 5. Merge orders and people sheets and find the top 3 managers based on sales.

# %%
data1=pd.read_excel('./Desktop/python final assessment.xlsx')

# %%
data
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       33994  CA-2012-SM20320140-40985 2012-03-17 2012-03-22  Standard Class
# 1       38123  CA-2014-TC20980140-41915 2014-10-03 2014-10-10  Standard Class
# 2       39450  CA-2015-RB19360140-42087 2015-03-24 2015-03-26     First Class
# 3       33920  CA-2015-TA21385140-42300 2015-10-23 2015-10-25     First Class
# 4       35487  CA-2015-HL15040140-42326 2015-11-18 2015-11-23  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51285   33403  US-2012-HG14965140-41177 2012-09-25 2012-09-25        Same Day
# 51286   36008  CA-2012-JO15280140-40998 2012-03-30 2012-03-30        Same Day
# 51287   39955  CA-2014-KB16600140-41812 2014-06-22 2014-06-26  Standard Class
# 51288   40589  CA-2015-RS19765140-42066 2015-03-03 2015-03-03        Same Day
# 51289   35398  US-2015-ZC21910140-42175 2015-06-20 2015-06-24  Standard Class
#
# ...

# %%
data3=pd.merge(data,data1,how="left",on='Region')

# %%
data3
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       33994  CA-2012-SM20320140-40985 2012-03-17 2012-03-22  Standard Class
# 1       38123  CA-2014-TC20980140-41915 2014-10-03 2014-10-10  Standard Class
# 2       39450  CA-2015-RB19360140-42087 2015-03-24 2015-03-26     First Class
# 3       33920  CA-2015-TA21385140-42300 2015-10-23 2015-10-25     First Class
# 4       35487  CA-2015-HL15040140-42326 2015-11-18 2015-11-23  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51285   33403  US-2012-HG14965140-41177 2012-09-25 2012-09-25        Same Day
# 51286   36008  CA-2012-JO15280140-40998 2012-03-30 2012-03-30        Same Day
# 51287   39955  CA-2014-KB16600140-41812 2014-06-22 2014-06-26  Standard Class
# 51288   40589  CA-2015-RS19765140-42066 2015-03-03 2015-03-03        Same Day
# 51289   35398  US-2015-ZC21910140-42175 2015-06-20 2015-06-24  Standard Class
#
# ...

# %%
top_3_manager=data3.sort_values('Sales',ascending=False)

# %%
top_3_manager
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       33994  CA-2012-SM20320140-40985 2012-03-17 2012-03-22  Standard Class
# 1       38123  CA-2014-TC20980140-41915 2014-10-03 2014-10-10  Standard Class
# 2       39450  CA-2015-RB19360140-42087 2015-03-24 2015-03-26     First Class
# 3       33920  CA-2015-TA21385140-42300 2015-10-23 2015-10-25     First Class
# 4       35487  CA-2015-HL15040140-42326 2015-11-18 2015-11-23  Standard Class
# ...       ...                       ...        ...        ...             ...
# 51285   33403  US-2012-HG14965140-41177 2012-09-25 2012-09-25        Same Day
# 51286   36008  CA-2012-JO15280140-40998 2012-03-30 2012-03-30        Same Day
# 51287   39955  CA-2014-KB16600140-41812 2014-06-22 2014-06-26  Standard Class
# 51288   40589  CA-2015-RS19765140-42066 2015-03-03 2015-03-03        Same Day
# 51289   35398  US-2015-ZC21910140-42175 2015-06-20 2015-06-24  Standard Class
#
# ...

# %%
top_3_manager[["Person_y"]].head(3)
# Out:
#           Person_y
# 0  Flannery Newton
# 1       Lon Bonher
# 2  Derrick Snyders

# %% [markdown]
# # 6.Plot a bar chart between the sum of sales of each product category

# %%
df['avg_sales']= df['Sales'].mean()

# %%
import matplotlib.pyplot as plot
from matplotlib import style

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 29 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
def dispname(barplot):
    i=0
    for bar in barplot:
        bar_height= bar.get_height()
        plt.annotate(str(df2.Percentage[i])+'%',xy=(bar.get_x()+bar.get_width()/2,bar_height),xytext=(0,3),ha='center',va='bottom',textcoords='offset points')
        i=i+1

# %%
from importlib import reload
plt=reload(plt)

# %%
df2 = df[['Category','Sales']]

# %%
df2=df2['Category'].value_counts().rename_axis('Categories').reset_index(name='sumofsales')

# %%
df2
# Out:
#         Categories  sumofsales
# 0  Office Supplies       31289
# 1       Technology       10141
# 2        Furniture        9860

# %%
#to find the percentage
pertg=[]
sum_of_sales=df2['sumofsales'].sum()
for i in range(3):
    percentage_=(df2.sumofsales[i]/sum_of_sales)*100
    pertg.append(round(percentage_,2))

# %%
df2['Percentage']=pertg

# %%
df2
# Out:
#         Categories  sumofsales  Percentage
# 0  Office Supplies       31289       61.00
# 1       Technology       10141       19.77
# 2        Furniture        9860       19.22

# %%
plot.figure(figsize=[12,5])
barplot=plot.bar(df2['Categories'],df2['sumofsales'],width=0.2,color='black')
dispname(barplot)
plot.title('plotting sum of sales for each category,also showing the percentage sales')
plot.xlabel('Category')
plot.ylabel('Sum of sales')
plot.show()

# %% [markdown]
# # 7.Plot a scatter plot between sales and Profit

# %%
plt.figure(figsize=(10, 8), dpi=80)
plt.scatter(df.Sales,df.Profit,color='blue')
plt.title('scatter plot')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.ylim(-2000,2000)
plt.show()

# %%
df

# %% [markdown]
# # 8.Plot a pie chart between the top 3 countries and their total sales

# %%
top_country=data_names.head(3)

# %%
top_country
# Out:
#    Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0   33994  CA-2012-SM20320140-40985 2012-03-17 2012-03-22  Standard Class
# 1   38123  CA-2014-TC20980140-41915 2014-10-03 2014-10-10  Standard Class
# 2   39450  CA-2015-RB19360140-42087 2015-03-24 2015-03-26     First Class
#
#     Customer ID Customer Name      Segment  Postal Code          City  ...  \
# 0  SM-203201408   Sean Miller  Home Office      32216.0  Jacksonville  ...
# 1  TC-209801402  Tamara Chand    Corporate      47905.0     Lafayette  ...
# 2  RB-193601404  Raymond Buch     Consumer      98115.0       Seattle  ...
#
#   Sub-Category                                       Product Name     Sales  \
# 0     Machines  Cisco TelePresence System EX90 Videoconferenci...  22638.48
# 1      Copiers              Canon imageCLASS 2200 Advanced Copier  17499.95
# 2      Copiers              Canon imageCLASS 2200 Advanced Copier  13999.96
#
# ...

# %%
top_country.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# Person                    object
# Region.1                  object
# dtype: object

# %%
plt.pie(top_country["Sales"], labels=top_country["Sales"],startangle=90,shadow=True)
plt.title('Sales_for_Countries')
plt.legend(top_country.City,loc=3)
plt.show()
